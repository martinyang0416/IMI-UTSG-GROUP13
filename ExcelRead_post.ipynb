# %%
# import required libraries
import pandas as pd

# %%
# load the cmeg training data set:
df1 = pd.read_excel("training_set/cmeg_df_case_competition_scrambled_train.xlsx")
df1
# Out:
#          ROW  Corp_Residence_Country_Code  BR Code  Period  CUSTOMER_ID  \
# 0       5662                            1        5  2017Q4         1576
# 1      16369                            1        5  2015Q4         4545
# 2       2326                            0       12  2015Q2          648
# 3      38131                            0       19  2017Q3        13395
# 4      36605                            0       19  2015Q3        12998
# ...      ...                          ...      ...     ...          ...
# 28219   4906                            0        3  2016Q1         1357
# 28220  14151                            0       32  2017Q2         3969
# 28221   4302                            0        4  2019Q4         1190
# 28222  33510                            1        5  2019Q2        11429
# 28223   3971                            0        2  2015Q4         1097
#
#        Final_IG  B_PLUS_FLAG      EBITDA_Y0      EBITDA_Y1      EBITDA_Y2  \
# 0             5            1  575863.911214  602838.635998  583646.469630
# 1             7            1  599469.364624  615373.028208  612705.047096
# 2             8            1  613829.072017  575020.270272            NaN
# 3             5            1  585059.299344  581915.869330  594033.887481
# 4             6            1  605966.227164  593540.797737            NaN
# ...         ...          ...            ...            ...            ...
# 28219         4            1  634083.805367  596560.877037  585727.302685
# 28220         8            1  599167.455873  606599.776848  584777.909011
# 28221        12            0  585833.702024  600921.790966  613953.083276
# 28222         3            1  614960.631181  629560.585953  601757.595313
# 28223         9            0  593313.219804  610231.301363  622599.657205
#
#        ...  RETAINED_EARNINGS_Y1  RETAINED_EARNINGS_Y2  RETAINED_EARNINGS_Y3  \
# 0      ...         597031.247138         600893.706501         590802.111805
# 1      ...         621227.589036         594596.565749                   NaN
# 2      ...         619380.184641                   NaN                   NaN
# 3      ...         613180.540495         585288.491695         576526.161339
# 4      ...         575840.218046                   NaN                   NaN
# ...    ...                   ...                   ...                   ...
# 28219  ...         656592.126133         642982.723046                   NaN
# 28220  ...         618186.354843         568748.820980         618458.927301
# 28221  ...         580208.946781         600945.808669         608159.475608
# 28222  ...         628181.499247         609814.691684                   NaN
# 28223  ...         582354.881917                   NaN                   NaN
#
#               FCF_Y0         FCF_Y1         FCF_Y2         CCE_Y0  \
# 0      606861.990009  570523.662855            NaN  575350.400174
# 1                NaN            NaN            NaN  615104.995291
# 2      586607.548841  584847.736742            NaN  580199.620976
# 3      604725.209898  579187.232468  628406.498679  587097.755174
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 28219            NaN            NaN            NaN  608441.635403
# 28220  577743.751242  626908.014329  616628.710862  569798.734315
# 28221  590630.554572  605801.382673  611544.549810  607451.340542
# 28222  578897.753796  578304.849869  582939.116033  619087.326928
# 28223  576106.382457  629278.781797            NaN  603604.124963
#
#               CCE_Y1         CCE_Y2         CCE_Y3
# 0      571025.770698  603242.309649  622846.821734
# 1      615953.218376  589034.257388            NaN
# 2      605016.760749            NaN            NaN
# 3      615814.454998  599338.620711  588454.089187
# 4                NaN            NaN            NaN
# ...              ...            ...            ...
# 28219  576775.438473  613428.371878            NaN
# 28220  613394.373020  610823.134228  625507.099554
# 28221  569783.344574  590339.895563  581869.457144
# 28222  586553.512559  583233.996485            NaN
# 28223  581098.200055            NaN            NaN
#
# [28224 rows x 125 columns]

# %%
# read_excel reads the first sheet within the workbook by default
# We can also read the second sheet with the data key
dk1 = pd.read_excel("training_set/cmeg_df_case_competition_scrambled_train.xlsx", sheet_name=1)
dk1
# Out:
#                           Column                                  Description
# 0    Corp_Residence_Country_Code                                 Country Code
# 1                        BR Code                                Industry Code
# 2                         Period                                 Year quarter
# 3                 Period_Numeric                                      Quarter
# 4        CUSTOMER_ID (Tokenized)                                 Technical ID
# ..                           ...                                          ...
# 122                       FCF_Y2                  Free Cash Flow of a year -2
# 123                       CCE_Y0  Cash and Cash Equivalents of a current year
# 124                       CCE_Y1      Cash and Cash Equivalents  of a year -1
# 125                       CCE_Y2       Cash and Cash Equivalents of a year -2
# 126                       CCE_Y3       Cash and Cash Equivalents of a year -3
#
# [127 rows x 2 columns]

# %%
# load the general_industries training data set:
df2 = pd.read_excel("training_set/general_industries_df_case_competition_scrambled_train.xlsx")
df2
# Out:
#          ROW  Corp_Residence_Country_Code  BR Code  Period  CUSTOMER_ID  \
# 0      28464                            2        4  2017Q1         8228
# 1      39693                            3       63  2018Q4        12315
# 2      19535                           15       13  2018Q2         5504
# 3       4286                            2        4  2020Q1         1107
# 4      39621                           59       30  2019Q2        12294
# ...      ...                          ...      ...     ...          ...
# 28459  20573                            2        4  2018Q2         5806
# 28460  38928                           18        8  2017Q2        12117
# 28461  10854                            2        4  2014Q3         2956
# 28462  33948                            0        2  2020Q1        10025
# 28463   4210                            2        4  2017Q4         1080
#
#        Final_IG  B_PLUS_FLAG      EBITDA_Y0      EBITDA_Y1      EBITDA_Y2  \
# 0             8            1  365604.767017  341575.264490  368053.254720
# 1             7            1  748378.874160  593272.587785  606298.959960
# 2             6            1  379351.685119  394182.092405  380051.883962
# 3             8            1  363552.396086  371786.373645  371542.067484
# 4             8            1  368530.936855  367450.033454  358297.870364
# ...         ...          ...            ...            ...            ...
# 28459         9            0  348505.392802  373179.338715            NaN
# 28460        10            0  357301.991857  367388.379039  349205.256065
# 28461        11            0  365507.355685            NaN            NaN
# 28462         8            1  377836.275125  376242.444137  372143.872953
# 28463        17            0  368492.717036  367002.205368  354229.329553
#
#        ...  RETAINED_EARNINGS_Y1  RETAINED_EARNINGS_Y2  RETAINED_EARNINGS_Y3  \
# 0      ...         373864.705143         369694.522194         339867.222381
# 1      ...         605658.829652         510342.796894         705321.337524
# 2      ...         372940.581700         356833.167530         367306.071112
# 3      ...         356411.077910         342327.527537         366354.742233
# 4      ...         355608.575949         351911.163051                   NaN
# ...    ...                   ...                   ...                   ...
# 28459  ...         355619.097419                   NaN                   NaN
# 28460  ...         346997.932098         344756.293543                   NaN
# 28461  ...                   NaN                   NaN                   NaN
# 28462  ...         361947.178645         361494.570129         362702.289455
# 28463  ...         350544.343452         364616.468437         341982.336335
#
#               FCF_Y0         FCF_Y1         FCF_Y2         CCE_Y0  \
# 0      364236.569625            NaN            NaN  350599.333501
# 1      577814.590748  464235.132963  617901.795410  551960.406798
# 2      387950.807778  389893.413929  364549.242197  370680.802471
# 3      372030.051844  374857.163137  362254.021673  366611.785072
# 4                NaN            NaN            NaN  350505.223417
# ...              ...            ...            ...            ...
# 28459  337971.276488  367353.545028            NaN  360676.534767
# 28460  342960.238351  363464.715489  357904.387125  346567.174005
# 28461  371363.917176            NaN            NaN  361846.758424
# 28462  366539.529122  347669.650130  363206.555427  371467.255282
# 28463  365008.789069  344075.615367  344568.508501  349415.758960
#
#               CCE_Y1         CCE_Y2         CCE_Y3
# 0      368971.137940  342125.692144  360512.171013
# 1      460369.335404  391812.102849  416234.858630
# 2      371698.484955  362778.394801  366921.505401
# 3      344896.040064  367964.677168  350629.253166
# 4      347030.412041  360238.097158            NaN
# ...              ...            ...            ...
# 28459  369726.157642            NaN            NaN
# 28460  363888.487231  340606.091857            NaN
# 28461            NaN            NaN            NaN
# 28462  341805.183266  344234.449692  353776.883119
# 28463  350153.946254  357958.325385  373797.075229
#
# [28464 rows x 125 columns]

# %%
# read the second sheet with the data key
dk2 = pd.read_excel("training_set/general_industries_df_case_competition_scrambled_train.xlsx", sheet_name=1)
dk2
# Out:
#                           Column                                  Description
# 0    Corp_Residence_Country_Code                                 Country Code
# 1                        BR Code                                Industry Code
# 2                         Period                                 Year quarter
# 3                 Period_Numeric                                      Quarter
# 4        CUSTOMER_ID (Tokenized)                                 Technical ID
# ..                           ...                                          ...
# 122                       FCF_Y2                  Free Cash Flow of a year -2
# 123                       CCE_Y0  Cash and Cash Equivalents of a current year
# 124                       CCE_Y1      Cash and Cash Equivalents  of a year -1
# 125                       CCE_Y2       Cash and Cash Equivalents of a year -2
# 126                       CCE_Y3       Cash and Cash Equivalents of a year -3
#
# [127 rows x 2 columns]

# %%
# save in CSV format (without index column)
df1.to_csv("cmeg_df_case_competition_scrambled_train.csv", index=False)
dk1.to_csv("cmeg_df_case_competition_scrambled_train_datakey.csv", index=False)
df2.to_csv("general_industries_df_case_competition_scrambled_train.csv", index=False)
dk2.to_csv("general_industries_df_case_competition_scrambled_train_datakey.csv", index=False)
